# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"




# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
  #  city_url = f'{BASE_URL}q={city.replace(" ", "+")}' 

    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

   # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        status_code = response.status_code
        if status_code == 200:
            city_weather = response.json()
        else:
            city_weather = {} # failed request
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather.get("coord", {}).get("lat")
        city_lng = city_weather.get("coord", {}).get("lon")
        city_max_temp = city_weather.get("main", {}).get("temp_max")
        city_humidity = city_weather.get("main", {}).get("humidity")
        city_clouds = city_weather.get("clouds", {}).get("all")
        city_wind = city_weather.get("wind", {}).get("speed")
        city_country = city_weather.get("sys", {}).get("country")
        city_date = city_weather.get("dt")
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print("City not found. Skipping...")
        print(e)
        pass
    # Sleep for 1 second - Kourt aksed us to add and Prof showed us how to do it
    time.sleep(1)
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | laguna
# Processing Record 2 of Set 1 | novovyazniki
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | nizhneudinsk
# Processing Record 5 of Set 1 | beruniy
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | la ronge
# Processing Record 8 of Set 1 | huocheng
# Processing Record 9 of Set 1 | northam
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | kayenta
# Processing Record 12 of Set 1 | ust-nera
# Processing Record 13 of Set 1 | nemuro
# Processing Record 14 of Set 1 | brigantine
# Processing Record 15 of Set 1 | koh kong
# Processing Record 16 of Set 1 | mata-utu
# Processing Record 17 of Set 1 | billings
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | dunedin
# Processing Record 20 of Set 1 | kulhudhuffushi
# Processing Record 21 of Set 1 | tulun
# Processing Record 22 of Set 1 | uturoa
# Processing Record 23 of Set 1 | hawaiian paradise park
# Processing Record 24 of Set 1 | baker city
# Processing Record 25 of Set 1 | ghat
# Processing Record 26 of Set 1 | chubbuck
# Processing Record 27 of Set 1 | naze
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | andergrove
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | papatowai
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | grytviken
# Processing Record 35 of Set 1 | ugoofaaru
# Processing Record 36 of Set 1 | banff
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | nagqu
# Processing Record 41 of Set 1 | agat village
# Processing Record 42 of Set 1 | khvansar
# Processing Record 43 of Set 1 | ringas
# Processing Record 44 of Set 1 | paita
# Processing Record 45 of Set 1 | aasiaat
# Processing Record 46 of Set 1 | alotau
# Processing Record 47 of Set 1 | broome
# Processing Record 48 of Set 1 | eregli
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 0 of Set 2 | santa cruz
# Processing Record 1 of Set 2 | stanley
# Processing Record 2 of Set 2 | badger
# Processing Record 3 of Set 2 | titao
# Processing Record 4 of Set 2 | remire-montjoly
# Processing Record 5 of Set 2 | whakatane
# Processing Record 6 of Set 2 | tinajo
# Processing Record 7 of Set 2 | awash
# Processing Record 8 of Set 2 | ust'-charyshskaya pristan'
# Processing Record 9 of Set 2 | tazovsky
# Processing Record 10 of Set 2 | katsuura
# Processing Record 11 of Set 2 | hadibu
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | kupang
# Processing Record 14 of Set 2 | parnu
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | kyzyl-mazhalyk
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | hamilton
# Processing Record 20 of Set 2 | cobija
# Processing Record 21 of Set 2 | mao
# Processing Record 22 of Set 2 | beyneu
# Processing Record 23 of Set 2 | udachny
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | karatas
# Processing Record 26 of Set 2 | carhuamayo
# Processing Record 27 of Set 2 | arno
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | bilibino
# Processing Record 30 of Set 2 | seryshevo
# Processing Record 31 of Set 2 | mishan
# Processing Record 32 of Set 2 | san antonio de pale
# Processing Record 33 of Set 2 | sitka
# Processing Record 34 of Set 2 | akobo
# Processing Record 35 of Set 2 | ushuaia
# Processing Record 36 of Set 2 | pitea
# Processing Record 37 of Set 2 | garoowe
# Processing Record 38 of Set 2 | wailua homesteads
# Processing Record 39 of Set 2 | korsakov
# Processing Record 40 of Set 2 | campoverde
# Processing Record 41 of Set 2 | nikel
# Processing Record 42 of Set 2 | margaret river
# Processing Record 43 of Set 2 | afaahiti
# Processing Record 44 of Set 2 | sanya
# Processing Record 45 of Set 2 | antalaha
# Processing Record 46 of Set 2 | saipan
# Processing Record 47 of Set 2 | carutapera
# Processing Record 48 of Set 2 | tilcara
# Processing Record 49 of Set 2 | prince rupert
# Processing Record 0 of Set 3 | tateyama
# Processing Record 1 of Set 3 | vilyuysk
# Processing Record 2 of Set 3 | puerto aysen
# Processing Record 3 of Set 3 | bulata
# Processing Record 4 of Set 3 | tarime
# Processing Record 5 of Set 3 | coracora
# Processing Record 6 of Set 3 | colonia aurora
# Processing Record 7 of Set 3 | north bay
# Processing Record 8 of Set 3 | broken hill
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | cabedelo
# Processing Record 11 of Set 3 | erenhot
# Processing Record 12 of Set 3 | griffith
# Processing Record 13 of Set 3 | nueva villa de padilla
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | araci
# Processing Record 16 of Set 3 | puerto natales
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | quellon
# Processing Record 19 of Set 3 | cargados carajos
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | olonkinbyen
# Processing Record 22 of Set 3 | khorixas
# Processing Record 23 of Set 3 | paragominas
# Processing Record 24 of Set 3 | anadyr
# Processing Record 25 of Set 3 | humaita
# Processing Record 26 of Set 3 | kalagarh project colony
# Processing Record 27 of Set 3 | west end
# Processing Record 28 of Set 3 | sao gabriel da cachoeira
# Processing Record 29 of Set 3 | turbat
# Processing Record 30 of Set 3 | anzio
# Processing Record 31 of Set 3 | zhalantun
# Processing Record 32 of Set 3 | queenstown
# Processing Record 33 of Set 3 | sao vicente
# Processing Record 34 of Set 3 | chonchi
# Processing Record 35 of Set 3 | yeniseysk
# Processing Record 36 of Set 3 | morrinhos
# Processing Record 37 of Set 3 | vadso
# Processing Record 38 of Set 3 | sumenep
# Processing Record 39 of Set 3 | edinburgh of the seven seas
# Processing Record 40 of Set 3 | el bauga
# Processing Record 41 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 42 of Set 3 | kol'tsovo
# Processing Record 43 of Set 3 | skelleftea
# Processing Record 44 of Set 3 | al kharijah
# Processing Record 45 of Set 3 | rongelap
# Processing Record 46 of Set 3 | valle vista
# Processing Record 47 of Set 3 | hithadhoo
# Processing Record 48 of Set 3 | sinabang
# Processing Record 49 of Set 3 | blackmans bay
# Processing Record 0 of Set 4 | ketchikan
# Processing Record 1 of Set 4 | isafjordur
# Processing Record 2 of Set 4 | nuuk
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | mount pearl
# Processing Record 5 of Set 4 | haiku-pauwela
# Processing Record 6 of Set 4 | whitehorse
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | west island
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | inhambane
# Processing Record 11 of Set 4 | happy valley-goose bay
# Processing Record 12 of Set 4 | keflavik
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | port moresby
# Processing Record 15 of Set 4 | ijuw
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | st. john's
# Processing Record 18 of Set 4 | san andres
# Processing Record 19 of Set 4 | dedougou
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | martapura
# Processing Record 22 of Set 4 | okhotsk
# Processing Record 23 of Set 4 | atafu village
# Processing Record 24 of Set 4 | weno
# Processing Record 25 of Set 4 | invercargill
# Processing Record 26 of Set 4 | vila franca do campo
# Processing Record 27 of Set 4 | roswell
# Processing Record 28 of Set 4 | tymovskoye
# Processing Record 29 of Set 4 | minas de marcona
# Processing Record 30 of Set 4 | madras
# Processing Record 31 of Set 4 | virginia
# Processing Record 32 of Set 4 | quelimane
# Processing Record 33 of Set 4 | harstad
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | anan
# Processing Record 36 of Set 4 | nova prata
# Processing Record 37 of Set 4 | saratamata
# Processing Record 38 of Set 4 | kansanshi
# Processing Record 39 of Set 4 | george town
# Processing Record 40 of Set 4 | vorgashor
# Processing Record 41 of Set 4 | barah
# Processing Record 42 of Set 4 | kataragama
# Processing Record 43 of Set 4 | kijang
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | port douglas
# Processing Record 46 of Set 4 | bocaiuva
# Processing Record 47 of Set 4 | taiohae
# Processing Record 48 of Set 4 | changji
# Processing Record 49 of Set 4 | rudsar
# Processing Record 0 of Set 5 | lionel town
# Processing Record 1 of Set 5 | lahaina
# Processing Record 2 of Set 5 | ta`u
# Processing Record 3 of Set 5 | vingt cinq
# Processing Record 4 of Set 5 | mesquite
# Processing Record 5 of Set 5 | emerald
# Processing Record 6 of Set 5 | manakara
# Processing Record 7 of Set 5 | goure
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | susuman
# Processing Record 10 of Set 5 | navolato
# Processing Record 11 of Set 5 | yeppoon
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | turpan
# Processing Record 14 of Set 5 | yigo village
# Processing Record 15 of Set 5 | pijijiapan
# Processing Record 16 of Set 5 | zapala
# Processing Record 17 of Set 5 | cooma
# Processing Record 18 of Set 5 | cestos city
# Processing Record 19 of Set 5 | tehachapi
# Processing Record 20 of Set 5 | cukai
# Processing Record 21 of Set 5 | kristinestad
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | isieke
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | lipno
# Processing Record 26 of Set 5 | inongo
# Processing Record 27 of Set 5 | myrina
# Processing Record 28 of Set 5 | burlingame
# Processing Record 29 of Set 5 | itaituba
# Processing Record 30 of Set 5 | dryden
# Processing Record 31 of Set 5 | chibougamau
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | aljezur
# Processing Record 34 of Set 5 | kerikeri
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | callao
# Processing Record 38 of Set 5 | tsiombe
# Processing Record 39 of Set 5 | nova vicosa
# Processing Record 40 of Set 5 | neiafu
# Processing Record 41 of Set 5 | city of balikpapan
# Processing Record 42 of Set 5 | kismayo
# Processing Record 43 of Set 5 | greymouth
# Processing Record 44 of Set 5 | ulaangom
# Processing Record 45 of Set 5 | wuchang
# Processing Record 46 of Set 5 | amungan
# Processing Record 47 of Set 5 | lihue
# Processing Record 48 of Set 5 | geraldton
# Processing Record 49 of Set 5 | abraham's bay
# Processing Record 0 of Set 6 | revda
# Processing Record 1 of Set 6 | kapa'a
# Processing Record 2 of Set 6 | gurghiu
# Processing Record 3 of Set 6 | qamdo
# Processing Record 4 of Set 6 | geneina
# Processing Record 5 of Set 6 | rakops
# Processing Record 6 of Set 6 | dudinka
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | east london
# Processing Record 9 of Set 6 | kapuskasing
# Processing Record 10 of Set 6 | ar rass
# Processing Record 11 of Set 6 | tolanaro
# Processing Record 12 of Set 6 | buka
# Processing Record 13 of Set 6 | illizi
# Processing Record 14 of Set 6 | plastun
# Processing Record 15 of Set 6 | ivdel'
# Processing Record 16 of Set 6 | el porvenir
# Processing Record 17 of Set 6 | kingston
# Processing Record 18 of Set 6 | alaghsas
# Processing Record 19 of Set 6 | selfoss
# Processing Record 20 of Set 6 | la passe
# Processing Record 21 of Set 6 | shenandoah
# Processing Record 22 of Set 6 | alesund
# Processing Record 23 of Set 6 | colonia
# Processing Record 24 of Set 6 | kotlas
# Processing Record 25 of Set 6 | isla aguada
# Processing Record 26 of Set 6 | san vicente
# Processing Record 27 of Set 6 | malabar
# Processing Record 28 of Set 6 | kone
# Processing Record 29 of Set 6 | utrik
# Processing Record 30 of Set 6 | benjamin constant
# Processing Record 31 of Set 6 | loncoche
# Processing Record 32 of Set 6 | port mathurin
# Processing Record 33 of Set 6 | ondjiva
# Processing Record 34 of Set 6 | escarcega
# Processing Record 35 of Set 6 | port elizabeth
# Processing Record 36 of Set 6 | fedorovka
# Processing Record 37 of Set 6 | pisco
# Processing Record 38 of Set 6 | avarua
# Processing Record 39 of Set 6 | simanggang
# Processing Record 40 of Set 6 | madang
# Processing Record 41 of Set 6 | isle of lewis
# Processing Record 42 of Set 6 | zeerust
# Processing Record 43 of Set 6 | brisas de zicatela
# Processing Record 44 of Set 6 | crane
# Processing Record 45 of Set 6 | bhimunipatnam
# Processing Record 46 of Set 6 | vacha
# Processing Record 47 of Set 6 | bardai
# Processing Record 48 of Set 6 | ritchie
# Processing Record 49 of Set 6 | boundiali
# Processing Record 0 of Set 7 | sisimiut
# Processing Record 1 of Set 7 | zhumysker
# Processing Record 2 of Set 7 | camana
# Processing Record 3 of Set 7 | maun
# Processing Record 4 of Set 7 | avsallar
# Processing Record 5 of Set 7 | yakeshi
# Processing Record 6 of Set 7 | sao miguel do araguaia
# Processing Record 7 of Set 7 | hachinohe
# Processing Record 8 of Set 7 | marsh harbour
# Processing Record 9 of Set 7 | klyuchi
# Processing Record 10 of Set 7 | gokceada
# Processing Record 11 of Set 7 | regina
# Processing Record 12 of Set 7 | yanbu
# Processing Record 13 of Set 7 | nova sintra
# Processing Record 14 of Set 7 | box elder
# Processing Record 15 of Set 7 | sur
# Processing Record 16 of Set 7 | victoria de durango
# Processing Record 17 of Set 7 | mongo
# Processing Record 18 of Set 7 | kosiv
# Processing Record 19 of Set 7 | mokhsogollokh
# Processing Record 20 of Set 7 | qaqortoq
# Processing Record 21 of Set 7 | biasca
# Processing Record 22 of Set 7 | constantia
# Processing Record 23 of Set 7 | talnakh
# Processing Record 24 of Set 7 | berbera
# Processing Record 25 of Set 7 | awjilah
# Processing Record 26 of Set 7 | borogontsy
# Processing Record 27 of Set 7 | alvaraes
# Processing Record 28 of Set 7 | estacion coahuila
# Processing Record 29 of Set 7 | boguchany
# Processing Record 30 of Set 7 | kirensk
# Processing Record 31 of Set 7 | yurga
# Processing Record 32 of Set 7 | preobrazheniye
# Processing Record 33 of Set 7 | tromso
# Processing Record 34 of Set 7 | polyarnyy
# Processing Record 35 of Set 7 | saynshand
# Processing Record 36 of Set 7 | holualoa
# Processing Record 37 of Set 7 | windsor
# Processing Record 38 of Set 7 | saldanha
# Processing Record 39 of Set 7 | ocean shores
# Processing Record 40 of Set 7 | dwarka
# Processing Record 41 of Set 7 | tofol
# Processing Record 42 of Set 7 | san luis de la loma
# Processing Record 43 of Set 7 | alofi
# Processing Record 44 of Set 7 | puerto san carlos
# Processing Record 45 of Set 7 | kristiansund
# Processing Record 46 of Set 7 | kosong
# Processing Record 47 of Set 7 | westport
# Processing Record 48 of Set 7 | tarnogskiy gorodok
# Processing Record 49 of Set 7 | xai-xai
# Processing Record 0 of Set 8 | katsuren-haebaru
# Processing Record 1 of Set 8 | merizo village
# Processing Record 2 of Set 8 | diyarbakir
# Processing Record 3 of Set 8 | prince george
# Processing Record 4 of Set 8 | kez
# Processing Record 5 of Set 8 | suntar
# Processing Record 6 of Set 8 | tranovaho
# Processing Record 7 of Set 8 | inarajan village
# Processing Record 8 of Set 8 | caxito
# Processing Record 9 of Set 8 | port lincoln
# Processing Record 10 of Set 8 | shubarkuduk
# Processing Record 11 of Set 8 | karratha
# Processing Record 12 of Set 8 | princeville
# Processing Record 13 of Set 8 | kittila
# Processing Record 14 of Set 8 | bikenibeu village
# Processing Record 15 of Set 8 | tirebolu
# Processing Record 16 of Set 8 | tashla
# Processing Record 17 of Set 8 | igarka
# Processing Record 18 of Set 8 | island harbour
# Processing Record 19 of Set 8 | pijino del carmen
# Processing Record 20 of Set 8 | ola
# Processing Record 21 of Set 8 | 'ohonua
# Processing Record 22 of Set 8 | jamaame
# Processing Record 23 of Set 8 | parauapebas
# Processing Record 24 of Set 8 | puerto baquerizo moreno
# Processing Record 25 of Set 8 | ambalangoda
# Processing Record 26 of Set 8 | north platte
# Processing Record 27 of Set 8 | ahrensbok
# Processing Record 28 of Set 8 | terrace
# Processing Record 29 of Set 8 | san julian
# Processing Record 30 of Set 8 | yuzhno-kurilsk
# Processing Record 31 of Set 8 | porto novo
# Processing Record 32 of Set 8 | masterton
# Processing Record 33 of Set 8 | buala
# Processing Record 34 of Set 8 | san jose del guaviare
# Processing Record 35 of Set 8 | ponteareas
# Processing Record 36 of Set 8 | balcarce
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | acarau
# Processing Record 39 of Set 8 | myitkyina
# Processing Record 40 of Set 8 | bargara
# Processing Record 41 of Set 8 | coahuayana de hidalgo
# Processing Record 42 of Set 8 | galle
# Processing Record 43 of Set 8 | songyuan
# Processing Record 44 of Set 8 | smithers
# Processing Record 45 of Set 8 | tralee
# Processing Record 46 of Set 8 | tual
# Processing Record 47 of Set 8 | cole harbour
# Processing Record 48 of Set 8 | flying fish cove
# Processing Record 49 of Set 8 | ijero-ekiti
# Processing Record 0 of Set 9 | ouellah
# Processing Record 1 of Set 9 | camacupa
# Processing Record 2 of Set 9 | newman
# Processing Record 3 of Set 9 | wattegama
# Processing Record 4 of Set 9 | mstsislaw
# Processing Record 5 of Set 9 | nar'yan-mar
# Processing Record 6 of Set 9 | rio grande
# Processing Record 7 of Set 9 | santa elena de uairen
# Processing Record 8 of Set 9 | anloga
# Processing Record 9 of Set 9 | aransas pass
# Processing Record 10 of Set 9 | lishui
# Processing Record 11 of Set 9 | oranjemund
# Processing Record 12 of Set 9 | labytnangi
# Processing Record 13 of Set 9 | mossel bay
# Processing Record 14 of Set 9 | haapavesi
# Processing Record 15 of Set 9 | cruzeiro do sul
# Processing Record 16 of Set 9 | portland
# Processing Record 17 of Set 9 | enoch
# Processing Record 18 of Set 9 | le port
# Processing Record 19 of Set 9 | quzhou
# Processing Record 20 of Set 9 | sonsorol village
# Processing Record 21 of Set 9 | conception bay south
# Processing Record 22 of Set 9 | mandimba
# Processing Record 23 of Set 9 | ancud
# Processing Record 24 of Set 9 | mukalla
# Processing Record 25 of Set 9 | khadan khak
# Processing Record 26 of Set 9 | bodo
# Processing Record 27 of Set 9 | gribanovskiy
# Processing Record 28 of Set 9 | changqing
# Processing Record 29 of Set 9 | cabo san lucas
# Processing Record 30 of Set 9 | peniche
# Processing Record 31 of Set 9 | fisterra
# Processing Record 32 of Set 9 | darwin
# Processing Record 33 of Set 9 | apatzingan
# Processing Record 34 of Set 9 | turuncova
# Processing Record 35 of Set 9 | petukhovo
# Processing Record 36 of Set 9 | san rafael
# Processing Record 37 of Set 9 | salalah
# Processing Record 38 of Set 9 | bengbu
# Processing Record 39 of Set 9 | lyozna
# Processing Record 40 of Set 9 | errachidia
# Processing Record 41 of Set 9 | huilong
# Processing Record 42 of Set 9 | hailey
# Processing Record 43 of Set 9 | tura
# Processing Record 44 of Set 9 | berezovyy
# Processing Record 45 of Set 9 | eureka
# Processing Record 46 of Set 9 | gorontalo
# Processing Record 47 of Set 9 | ridder
# Processing Record 48 of Set 9 | esmeralda
# Processing Record 49 of Set 9 | cuatro cienegas de carranza
# Processing Record 0 of Set 10 | maba
# Processing Record 1 of Set 10 | raja
# Processing Record 2 of Set 10 | coquimbo
# Processing Record 3 of Set 10 | sooke
# Processing Record 4 of Set 10 | namanga
# Processing Record 5 of Set 10 | magadan
# Processing Record 6 of Set 10 | soto la marina
# Processing Record 7 of Set 10 | bouarfa
# Processing Record 8 of Set 10 | enewetak
# Processing Record 9 of Set 10 | filadelfia
# Processing Record 10 of Set 10 | severo-yeniseyskiy
# Processing Record 11 of Set 10 | olyokminsk
# Processing Record 12 of Set 10 | yaren
# Processing Record 13 of Set 10 | usinsk
# Processing Record 14 of Set 10 | beneditinos
# Processing Record 15 of Set 10 | lavaur
# Processing Record 16 of Set 10 | rikaze
# Processing Record 17 of Set 10 | salahonda
# Processing Record 18 of Set 10 | praya
# Processing Record 19 of Set 10 | klaksvik
# Processing Record 20 of Set 10 | watseka
# Processing Record 21 of Set 10 | fukuecho
# Processing Record 22 of Set 10 | sarandi
# Processing Record 23 of Set 10 | pizarro
# Processing Record 24 of Set 10 | millington
# Processing Record 25 of Set 10 | khanty-mansiysk
# Processing Record 26 of Set 10 | suva
# Processing Record 27 of Set 10 | ain sefra
# Processing Record 28 of Set 10 | vilyuchinsk
# Processing Record 29 of Set 10 | fomboni
# Processing Record 30 of Set 10 | santa ponsa
# Processing Record 31 of Set 10 | yeed
# Processing Record 32 of Set 10 | ahau
# Processing Record 33 of Set 10 | chicxulub puerto
# Processing Record 34 of Set 10 | miquelon
# Processing Record 35 of Set 10 | sumbawa besar
# Processing Record 36 of Set 10 | rexburg
# Processing Record 37 of Set 10 | medicine hat
# Processing Record 38 of Set 10 | bamboo flat
# Processing Record 39 of Set 10 | horta
# Processing Record 40 of Set 10 | chegdomyn
# Processing Record 41 of Set 10 | pickering
# Processing Record 42 of Set 10 | olinda
# Processing Record 43 of Set 10 | tulagi
# Processing Record 44 of Set 10 | ad dilam
# Processing Record 45 of Set 10 | howrah
# Processing Record 46 of Set 10 | galliano
# Processing Record 47 of Set 10 | khor
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | east honolulu
# Processing Record 0 of Set 11 | iskateley
# Processing Record 1 of Set 11 | beacon square
# Processing Record 2 of Set 11 | el nido
# Processing Record 3 of Set 11 | kiunga
# Processing Record 4 of Set 11 | ad dawadimi
# Processing Record 5 of Set 11 | namibe
# Processing Record 6 of Set 11 | cartagena
# Processing Record 7 of Set 11 | kasongo-lunda
# Processing Record 8 of Set 11 | tarawa
# Processing Record 9 of Set 11 | beyla
# Processing Record 10 of Set 11 | tanumah
# Processing Record 11 of Set 11 | ad dabbah
# Processing Record 12 of Set 11 | manokwari
# Processing Record 13 of Set 11 | ad darb
# Processing Record 14 of Set 11 | lajinha
# Processing Record 15 of Set 11 | bakhchysarai
# Processing Record 16 of Set 11 | sao jose da coroa grande
# Processing Record 17 of Set 11 | luganville
# Processing Record 18 of Set 11 | bengkulu
# Processing Record 19 of Set 11 | aykhal
# Processing Record 20 of Set 11 | opuwo
# Processing Record 21 of Set 11 | linqiong
# Processing Record 22 of Set 11 | kitimat
# Processing Record 23 of Set 11 | neyriz
# Processing Record 24 of Set 11 | fale old settlement
# Processing Record 25 of Set 11 | kakonko
# Processing Record 26 of Set 11 | novyy urgal
# Processing Record 27 of Set 11 | tamanrasset
# Processing Record 28 of Set 11 | mont-joli
# Processing Record 29 of Set 11 | villanueva
# Processing Record 30 of Set 11 | mezgor'e
# Processing Record 31 of Set 11 | that phanom
# Processing Record 32 of Set 11 | prado
# Processing Record 33 of Set 11 | atbasar
# Processing Record 34 of Set 11 | toyoshina
# Processing Record 35 of Set 11 | valparaiso
# Processing Record 36 of Set 11 | aripuana
# Processing Record 37 of Set 11 | pibor
# Processing Record 38 of Set 11 | antsiranana
# Processing Record 39 of Set 11 | buncrana
# Processing Record 40 of Set 11 | floro
# Processing Record 41 of Set 11 | al qitena
# Processing Record 42 of Set 11 | kushiro
# Processing Record 43 of Set 11 | corner brook
# Processing Record 44 of Set 11 | old town
# Processing Record 45 of Set 11 | basco
# Processing Record 46 of Set 11 | severobaykal'sk
# Processing Record 47 of Set 11 | es castell
# Processing Record 48 of Set 11 | maheshwar
# Processing Record 49 of Set 11 | piti village
# Processing Record 0 of Set 12 | kuchinarai
# Processing Record 1 of Set 12 | egilsstadir
# Processing Record 2 of Set 12 | arawa
# Processing Record 3 of Set 12 | zelenogorsk
# Processing Record 4 of Set 12 | puyang chengguanzhen
# Processing Record 5 of Set 12 | avallon
# Processing Record 6 of Set 12 | hilo
# Processing Record 7 of Set 12 | muli
# Processing Record 8 of Set 12 | n'zeto
# Processing Record 9 of Set 12 | mogocha
# Processing Record 10 of Set 12 | simpang
# Processing Record 11 of Set 12 | palmerston
# Processing Record 12 of Set 12 | ozernyy
# Processing Record 13 of Set 12 | outapi
# Processing Record 14 of Set 12 | aiquile
# Processing Record 15 of Set 12 | nakamura
# Processing Record 16 of Set 12 | taunggyi
# Processing Record 17 of Set 12 | itoman
# Processing Record 18 of Set 12 | dodge city
# Processing Record 19 of Set 12 | deqen
# Processing Record 20 of Set 12 | igualada
# Processing Record 21 of Set 12 | richards bay
# Processing Record 22 of Set 12 | palmer
# Processing Record 23 of Set 12 | villa gesell
# Processing Record 24 of Set 12 | shetpe
# Processing Record 25 of Set 12 | corinto
# Processing Record 26 of Set 12 | saint-francois
# Processing Record 27 of Set 12 | oroqen zizhiqi
# Processing Record 28 of Set 12 | nakhon sawan
# Processing Record 29 of Set 12 | lensk
# Processing Record 30 of Set 12 | pacasmayo
# Processing Record 31 of Set 12 | sarmiento
# Processing Record 32 of Set 12 | valentin gomez farias
# Processing Record 33 of Set 12 | valley east
# Processing Record 34 of Set 12 | vohipaho
# Processing Record 35 of Set 12 | daru
# Processing Record 36 of Set 12 | parry sound
# Processing Record 37 of Set 12 | hihifo
# Processing Record 38 of Set 12 | vila velha
# Processing Record 39 of Set 12 | sosnovka
# Processing Record 40 of Set 12 | gwasoro
# Processing Record 41 of Set 12 | port saint john's
# Processing Record 42 of Set 12 | bargaal
# Processing Record 43 of Set 12 | imbituba
# Processing Record 44 of Set 12 | xiongzhou
# Processing Record 45 of Set 12 | tshabong
# Processing Record 46 of Set 12 | rawson
# Processing Record 47 of Set 12 | bolderaja
# Processing Record 48 of Set 12 | ilhabela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          599
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        laguna  38.4210 -121.4238     35.35      31.0         0.0
# 1  novovyazniki  56.1975   42.1711     10.60      91.0         0.0
# 2         tiksi  71.6872  128.8694     12.12      63.0       100.0
# 3  nizhneudinsk  54.9076   99.0276      8.84      74.0         9.0
# 4       beruniy  41.6911   60.7525     26.98      50.0         0.0
#
#    Wind Speed Country          Date
# 0        2.57      US  1.719006e+09
# 1        2.88      RU  1.719006e+09
# 2        3.50      RU  1.719006e+09
# 3        2.30      RU  1.719006e+09
# 4        3.09      UZ  1.719006e+09

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              laguna  38.4210 -121.4238     35.35      31.0         0.0
# 1        novovyazniki  56.1975   42.1711     10.60      91.0         0.0
# 2               tiksi  71.6872  128.8694     12.12      63.0       100.0
# 3        nizhneudinsk  54.9076   99.0276      8.84      74.0         9.0
# 4             beruniy  41.6911   60.7525     26.98      50.0         0.0
#
#          Wind Speed Country          Date
# City_ID
# 0              2.57      US  1.719006e+09
# 1              2.88      RU  1.719006e+09
# 2              3.50      RU  1.719006e+09
# 3              2.30      RU  1.719006e+09
# 4              3.09      UZ  1.719006e+09

# %%
# Check for Null Values
city_data_df.loc[pd.isnull(city_data_df.Lat)]
# Out:
#                       City  Lat  Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 7                 huocheng  NaN  NaN       NaN       NaN         NaN
# 45                  alotau  NaN  NaN       NaN       NaN         NaN
# 119       cargados carajos  NaN  NaN       NaN       NaN         NaN
# 165                   ijuw  NaN  NaN       NaN       NaN         NaN
# 187             saratamata  NaN  NaN       NaN       NaN         NaN
# 192             kataragama  NaN  NaN       NaN       NaN         NaN
# 197                taiohae  NaN  NaN       NaN       NaN         NaN
# 203             vingt cinq  NaN  NaN       NaN       NaN         NaN
# 249          abraham's bay  NaN  NaN       NaN       NaN         NaN
# 291          isle of lewis  NaN  NaN       NaN       NaN         NaN
# 344      puerto san carlos  NaN  NaN       NaN       NaN         NaN
# 356              tranovaho  NaN  NaN       NaN       NaN         NaN
# 371                'ohonua  NaN  NaN       NaN       NaN         NaN
# 390                bargara  NaN  NaN       NaN       NaN         NaN
# 400                ouellah  NaN  NaN       NaN       NaN         NaN
# 420       sonsorol village  NaN  NaN       NaN       NaN         NaN
# 422               mandimba  NaN  NaN       NaN       NaN         NaN
# 434              turuncova  NaN  NaN       NaN       NaN         NaN
# 482                   ahau  NaN  NaN       NaN       NaN         NaN
# 483       chicxulub puerto  NaN  NaN       NaN       NaN         NaN
# 499          east honolulu  NaN  NaN       NaN       NaN         NaN
# 530               mezgor'e  NaN  NaN       NaN       NaN         NaN
# 537                  pibor  NaN  NaN       NaN       NaN         NaN
# 563                 outapi  NaN  NaN       NaN       NaN         NaN
# 583            valley east  NaN  NaN       NaN       NaN         NaN
# 584               vohipaho  NaN  NaN       NaN       NaN         NaN
# 587                 hihifo  NaN  NaN       NaN       NaN         NaN
# 590                gwasoro  NaN  NaN       NaN       NaN         NaN
#
#          Wind Speed Country  Date
# City_ID
# 7               NaN     NaN   NaN
# 45              NaN     NaN   NaN
# 119             NaN     NaN   NaN
# 165             NaN     NaN   NaN
# 187             NaN     NaN   NaN
# 192             NaN     NaN   NaN
# 197             NaN     NaN   NaN
# 203             NaN     NaN   NaN
# 249             NaN     NaN   NaN
# 291             NaN     NaN   NaN
# 344             NaN     NaN   NaN
# 356             NaN     NaN   NaN
# 371             NaN     NaN   NaN
# 390             NaN     NaN   NaN
# 400             NaN     NaN   NaN
# 420             NaN     NaN   NaN
# 422             NaN     NaN   NaN
# 434             NaN     NaN   NaN
# 482             NaN     NaN   NaN
# 483             NaN     NaN   NaN
# 499             NaN     NaN   NaN
# 530             NaN     NaN   NaN
# 537             NaN     NaN   NaN
# 563             NaN     NaN   NaN
# 583             NaN     NaN   NaN
# 584             NaN     NaN   NaN
# 587             NaN     NaN   NaN
# 590             NaN     NaN   NaN

# %%
# Drop Null Values
clean_df = city_data_df.dropna(how="any").reset_index()
clean_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        laguna  38.4210 -121.4238     35.35      31.0         0.0
# 1        1  novovyazniki  56.1975   42.1711     10.60      91.0         0.0
# 2        2         tiksi  71.6872  128.8694     12.12      63.0       100.0
# 3        3  nizhneudinsk  54.9076   99.0276      8.84      74.0         9.0
# 4        4       beruniy  41.6911   60.7525     26.98      50.0         0.0
#
#    Wind Speed Country          Date
# 0        2.57      US  1.719006e+09
# 1        2.88      RU  1.719006e+09
# 2        3.50      RU  1.719006e+09
# 3        2.30      RU  1.719006e+09
# 4        3.09      UZ  1.719006e+09

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x = clean_df.Lat
y = clean_df["Max Temp"]
# Incorporate the other graph properties
plt.figure(figsize=(10, 6))
plt.scatter(x, y, facecolor="rebeccapurple", edgecolor="black", s=100)
plt.xlabel("Latitude", fontsize=14, fontname="Arial")
plt.ylabel("Temperature (F)", fontsize=14, fontname="Arial")
plt.title("Latitude vs Temperature", fontname="Arial",fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
# Save the figure
plt.savefig("output_data/Fig1.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for Latitude Vs. Humidity
x = clean_df.Lat
y = clean_df.Humidity
# Incorporate the other graph properties
plt.figure(figsize=(10, 6))
plt.scatter(x, y, facecolor="rebeccapurple", edgecolor="black", s=100)
plt.xlabel("Latitude", fontsize=14, fontname="Arial")
plt.ylabel("Humidity", fontsize=14, fontname="Arial")
plt.title("Latitude vs Humidity", fontname="Arial",fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
# Save the figure
plt.savefig("output_data/Fig2.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for Latitude Vs. Humidity
x = clean_df.Lat
y = clean_df.Cloudiness
# Incorporate the other graph properties
plt.figure(figsize=(10, 6))
plt.scatter(x, y, facecolor="rebeccapurple", edgecolor="black", s=100)
plt.xlabel("Latitude", fontsize=14, fontname="Arial")
plt.ylabel("Cloudines", fontsize=14, fontname="Arial")
plt.title("Latitude vs Cloudines", fontname="Arial",fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
# Save the figure
plt.savefig("output_data/Fig3.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Wind Speed"],
    edgecolor="black", 
    linewidths=1, 
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed Plot (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              laguna  38.4210 -121.4238     35.35      31.0         0.0
# 1        novovyazniki  56.1975   42.1711     10.60      91.0         0.0
# 2               tiksi  71.6872  128.8694     12.12      63.0       100.0
# 3        nizhneudinsk  54.9076   99.0276      8.84      74.0         9.0
# 4             beruniy  41.6911   60.7525     26.98      50.0         0.0
#
#          Wind Speed Country          Date
# City_ID
# 0              2.57      US  1.719006e+09
# 1              2.88      RU  1.719006e+09
# 2              3.50      RU  1.719006e+09
# 3              2.30      RU  1.719006e+09
# 4              3.09      UZ  1.719006e+09

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5               bredasdorp -34.5322   20.0403     13.20      84.0        35.0
# 15                mata-utu -13.2816 -176.1745     27.82      78.0        59.0
# 17       port-aux-francais -49.3500   70.2167      1.99      93.0        73.0
# 18                 dunedin -45.8742  170.5036      7.67      74.0       100.0
# 21                  uturoa -16.7333 -151.4333     26.96      64.0        95.0
#
#          Wind Speed Country          Date
# City_ID
# 5              4.79      ZA  1.719006e+09
# 15             9.86      WF  1.719006e+09
# 17             6.32      TF  1.719006e+09
# 18             2.24      NZ  1.719006e+09
# 21             5.92      PF  1.719006e+09

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(40,10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50, 20))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-30,30))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 12))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
